# %%
import json
import time
from datetime import datetime
import codecs
import sys
import io
import matplotlib.pyplot as plt
import requests
import pandas as pd
import numpy as np
from itertools import cycle
import gmaps
# %matplotlib inline

# %%
import meetup.api
from config import api_key
from config2 import gkey
client = meetup.api.Client()
client.api_key = api_key
gmaps.configure(api_key=gkey)

# %%
url= 'https://api.meetup.com/2/cities?&sign=true&photo-host=public&page=50'
response1 = requests.get(url).json()
response1
# Out:
# {'results': [{'zip': '44101',
#    'country': 'us',
#    'localized_country_name': 'USA',
#    'distance': 8.213475245332047,
#    'city': 'Cleveland',
#    'lon': -81.66999816894531,
#    'ranking': 0,
#    'id': 44101,
#    'state': 'OH',
#    'member_count': 13715,
#    'lat': 41.4900016784668},
#   {'zip': '44301',
#    'country': 'us',
#    'localized_country_name': 'USA',
#    'distance': 31.232327600657683,
#    'city': 'Akron',
#    'lon': -81.5199966430664,
#    'ranking': 1,
#    'id': 44301,
#    'state': 'OH',
#    'member_count': 4700,
#    'lat': 41.040000915527344},
#   {'zip': '44701',
#    'country': 'us',
#    'localized_country_name': 'USA',
#    'distance': 52.2636928342518,
#    'city': 'Canton',
#    'lon': -81.44999694824219,
#    'ranking': 2,
#    'id': 44701,
#    'state': 'OH',
#    'member_count': 1830,
#    'lat': 40.72999954223633},
#   {'zip': '44107',
#    'country': 'us',
#    'localized_country_name': 'USA',
#    'distance': 3.2778223272738454,
#    'city': 'Lakewood',
#    'lon': -81.79000091552734,
#    'ranking': 3,
#    'id': 44107,
#    'state': 'OH',
#    'member_count': 1002,
#    'lat': 41.47999954223633},
#   {'zip': '44256',
#    'country': 'us',
#    'localized_country_name': 'USA',
#    'distance': 21.243891121398043,
#    'city': 'Medina',
#    'lon': -81.86000061035156,
#    'ranking': 4,
#    'id': 44256,
#    'state': 'OH',
#    'member_count': 752,
#    'lat': 41.130001068115234},
#   {'zip': '44145',
#    'country': 'us',
#    'localized_country_name': 'USA',
#    'distance': 6.258255895347396,
#    'city': 'Westlake',
#    'lon': -81.93000030517578,
#    'ranking': 5,
#    'id': 44145,
#    'state': 'OH',
#    'member_count': 709,
#    'lat': 41.45000076293945},
#   {'zip': '44060',
#    'country': 'us',
#    'localized_country_name': 'USA',
#    'distance': 30.462250816554576,
#    'city': 'Mentor',
#    'lon': -81.36000061035156,
#    'ranking': 6,
#    'id': 44060,
#    'state': 'OH',
#    'member_count': 481,
#    'lat': 41.720001220703125},
#   {'zip': '44221',
#    'country': 'us',
#    'localized_country_name': 'USA',
#    'distance': 27.030325099680198,
#    'city': 'Cuyahoga Falls',
#    'lon': -81.47000122070312,
#    'ranking': 7,
#    'id': 44221,
#    'state': 'OH',
#    'member_count': 475,
#    'lat': 41.13999938964844},
#   {'zip': '44122',
#    'country': 'us',
#    'localized_country_name': 'USA',
#    'distance': 15.759612327472423,
#    'city': 'Beachwood',
#    'lon': -81.51000213623047,
#    'ranking': 8,
#    'id': 44122,
#    'state': 'OH',
#    'member_count': 438,
#    'lat': 41.470001220703125},
#   {'zip': '44070',
#    'country': 'us',
#    'localized_country_name': 'USA',
#    'distance': 5.755250447268524,
#    'city': 'North Olmsted',
#    'lon': -81.91999816894531,
#    'ranking': 9,
#    'id': 44070,
#    'state': 'OH',
#    'member_count': 402,
#    'lat': 41.41999816894531},
#   {'zip': '44870',
#    'country': 'us',
#    'localized_country_name': 'USA',
#    'distance': 47.709096588891924,
#    'city': 'Sandusky',
#    'lon': -82.7300033569336,
#    'ranking': 10,
#    'id': 44870,
#    'state': 'OH',
#    'member_count': 377,
#    'lat': 41.400001525878906},
#   {'zip': '44035',
#    'country': 'us',
#    'localized_country_name': 'USA',
#    'distance': 16.157112405821316,
#    'city': 'Elyria',
#    'lon': -82.11000061035156,
#    'ranking': 11,
#    'id': 44035,
#    'state': 'OH',
#    'member_count': 376,
#    'lat': 41.369998931884766},
#   {'zip': '44094',
#    'country': 'us',
#    'localized_country_name': 'USA',
#    'distance': 24.649513866380342,
#    'city': 'Willoughby',
#    'lon': -81.41999816894531,
#    'ranking': 12,
#    'id': 44094,
#    'state': 'OH',
#    'member_count': 352,
#    'lat': 41.63999938964844},
#   {'zip': '44136',
#    'country': 'us',
#    'localized_country_name': 'USA',
#    'distance': 8.708179144412782,
#    'city': 'Strongsville',
#    'lon': -81.83000183105469,
#    'ranking': 13,
#    'id': 44136,
#    'state': 'OH',
#    'member_count': 345,
#    'lat': 41.310001373291016},
#   {'zip': '44224',
#    'country': 'us',
#    'localized_country_name': 'USA',
#    'distance': 26.23085493733588,
#    'city': 'Stow',
#    'lon': -81.44999694824219,
#    'ranking': 14,
#    'id': 44224,
#    'state': 'OH',
#    'member_count': 337,
#    'lat': 41.16999816894531},
#   {'zip': '44481',
#    'country': 'us',
#    'localized_country_name': 'USA',
#    'distance': 51.213874266758445,
#    'city': 'Warren',
#    'lon': -80.86000061035156,
#    'ranking': 15,
#    'id': 44481,
#    'state': 'OH',
#    'member_count': 335,
#    'lat': 41.2400016784668},
#   {'zip': '44240',
#    'country': 'us',
#    'localized_country_name': 'USA',
#    'distance': 31.847322775198624,
#    'city': 'Kent',
#    'lon': -81.33000183105469,
#    'ranking': 16,
#    'id': 44240,
#    'state': 'OH',
#    'member_count': 327,
#    'lat': 41.150001525878906},
#   {'zip': '44077',
#    'country': 'us',
#    'localized_country_name': 'USA',
#    'distance': 34.95792820278506,
#    'city': 'Painesville',
#    'lon': -81.27999877929688,
#    'ranking': 17,
#    'id': 44077,
#    'state': 'OH',
#    'member_count': 289,
#    'lat': 41.75},
#   {'zip': '44720',
#    'country': 'us',
#    'localized_country_name': 'USA',
#    'distance': 41.991280095375025,
#    'city': 'North Canton',
#    'lon': -81.43000030517578,
#    'ranking': 18,
#    'id': 44720,
#    'state': 'OH',
#    'member_count': 284,
#    'lat': 40.900001525878906},
#   {'zip': '44646',
#    'country': 'us',
#    'localized_country_name': 'USA',
#    'distance': 46.453444943619296,
#    'city': 'Massillon',
#    'lon': -81.5199966430664,
#    'ranking': 19,
#    'id': 44646,
#    'state': 'OH',
#    'member_count': 270,
#    'lat': 40.79999923706055},
#   {'zip': '44212',
#    'country': 'us',
#    'localized_country_name': 'USA',
#    'distance': 12.83587080924236,
#    'city': 'Brunswick',
#    'lon': -81.83000183105469,
#    'ranking': 20,
#    'id': 44212,
#    'state': 'OH',
#    'member_count': 249,
#    'lat': 41.25},
#   {'zip': '44117',
#    'country': 'us',
#    'localized_country_name': 'USA',
#    'distance': 17.24865372313835,
#    'city': 'Euclid',
#    'lon': -81.52999877929688,
#    'ranking': 21,
#    'id': 44117,
#    'state': 'OH',
#    'member_count': 246,
#    'lat': 41.56999969482422},
#   {'zip': '44039',
#    'country': 'us',
#    'localized_country_name': 'USA',
#    'distance': 11.286178465997283,
#    'city': 'North Ridgeville',
#    'lon': -82.0199966430664,
#    'ranking': 22,
#    'id': 44039,
#    'state': 'OH',
#    'member_count': 223,
#    'lat': 41.38999938964844},
#   {'zip': '44133',
#    'country': 'us',
#    'localized_country_name': 'USA',
#    'distance': 8.767231213684653,
#    'city': 'North Royalton',
#    'lon': -81.73999786376953,
#    'ranking': 23,
#    'id': 44133,
#    'state': 'OH',
#    'member_count': 213,
#    'lat': 41.31999969482422},
#   {'zip': '44131',
#    'country': 'us',
#    'localized_country_name': 'USA',
#    'distance': 8.699493410942647,
#    'city': 'Independence',
#    'lon': -81.66000366210938,
#    'ranking': 24,
#    'id': 44131,
#    'state': 'OH',
#    'member_count': 211,
#    'lat': 41.380001068115234},
#   {'zip': '44139',
#    'country': 'us',
#    'localized_country_name': 'USA',
#    'distance': 19.47525938463626,
#    'city': 'Solon',
#    'lon': -81.44000244140625,
#    'ranking': 25,
#    'id': 44139,
#    'state': 'OH',
#    'member_count': 204,
#    'lat': 41.38999938964844},
#   {'zip': '44052',
#    'country': 'us',
#    'localized_country_name': 'USA',
#    'distance': 18.680737674470414,
#    'city': 'Lorain',
#    'lon': -82.16999816894531,
#    'ranking': 26,
#    'id': 44052,
#    'state': 'OH',
#    'member_count': 201,
#    'lat': 41.459999084472656},
#   {'zip': '44022',
#    'country': 'us',
#    'localized_country_name': 'USA',
#    'distance': 20.24743410674789,
#    'city': 'Chagrin Falls',
#    'lon': -81.41999816894531,
#    'ranking': 27,
#    'id': 44022,
#    'state': 'OH',
#    'member_count': 199,
#    'lat': 41.439998626708984},
#   {'zip': '44116',
#    'country': 'us',
#    'localized_country_name': 'USA',
#    'distance': 3.503529584839378,
#    'city': 'Rocky River',
#    'lon': -81.86000061035156,
#    'ranking': 28,
#    'id': 44116,
#    'state': 'OH',
#    'member_count': 198,
#    'lat': 41.470001220703125},
#   {'zip': '44146',
#    'country': 'us',
#    'localized_country_name': 'USA',
#    'distance': 14.88876479415635,
#    'city': 'Bedford',
#    'lon': -81.52999877929688,
#    'ranking': 29,
#    'id': 44146,
#    'state': 'OH',
#    'member_count': 187,
#    'lat': 41.38999938964844},
#   {'zip': '44087',
#    'country': 'us',
#    'localized_country_name': 'USA',
#    'distance': 20.346877845248915,
#    'city': 'Twinsburg',
#    'lon': -81.44999694824219,
#    'ranking': 30,
#    'id': 44087,
#    'state': 'OH',
#    'member_count': 182,
#    'lat': 41.31999969482422},
#   {'zip': '44691',
#    'country': 'us',
#    'localized_country_name': 'USA',
#    'distance': 43.90008881988164,
#    'city': 'Wooster',
#    'lon': -81.95999908447266,
#    'ranking': 31,
#    'id': 44691,
#    'state': 'OH',
#    'member_count': 167,
#    'lat': 40.810001373291016},
#   {'zip': '44095',
#    'country': 'us',
#    'localized_country_name': 'USA',
#    'distance': 24.22585163345254,
#    'city': 'Eastlake',
#    'lon': -81.44000244140625,
#    'ranking': 32,
#    'id': 44095,
#    'state': 'OH',
#    'member_count': 166,
#    'lat': 41.650001525878906},
#   {'zip': '44203',
#    'country': 'us',
#    'localized_country_name': 'USA',
#    'distance': 31.19111407248711,
#    'city': 'Barberton',
#    'lon': -81.61000061035156,
#    'ranking': 33,
#    'id': 44203,
#    'state': 'OH',
#    'member_count': 150,
#    'lat': 41.0099983215332},
#   {'zip': '44024',
#    'country': 'us',
#    'localized_country_name': 'USA',
#    'distance': 32.9232435410043,
#    'city': 'Chardon',
#    'lon': -81.19999694824219,
#    'ranking': 34,
#    'id': 44024,
#    'state': 'OH',
#    'member_count': 149,
#    'lat': 41.56999969482422},
#   {'zip': '44067',
#    'country': 'us',
#    'localized_country_name': 'USA',
#    'distance': 15.70218312023781,
#    'city': 'Northfield',
#    'lon': -81.55000305175781,
#    'ranking': 35,
#    'id': 44067,
#    'state': 'OH',
#    'member_count': 142,
#    'lat': 41.31999969482422},
#   {'zip': '44140',
#    'country': 'us',
#    'localized_country_name': 'USA',
#    'distance': 6.803895320564222,
#    'city': 'Bay Village',
#    'lon': -81.91999816894531,
#    'ranking': 36,
#    'id': 44140,
#    'state': 'OH',
#    'member_count': 137,
#    'lat': 41.4900016784668},
#   {'zip': '44017',
#    'country': 'us',
#    'localized_country_name': 'USA',
#    'distance': 5.177501655590045,
#    'city': 'Berea',
#    'lon': -81.86000061035156,
#    'ranking': 37,
#    'id': 44017,
#    'state': 'OH',
#    'member_count': 132,
#    'lat': 41.369998931884766},
#   {'zip': '44138',
#    'country': 'us',
#    'localized_country_name': 'USA',
#    'distance': 6.826845288847647,
#    'city': 'Olmsted Falls',
#    'lon': -81.91999816894531,
#    'ranking': 38,
#    'id': 44138,
#    'state': 'OH',
#    'member_count': 131,
#    'lat': 41.380001068115234},
#   {'zip': '44012',
#    'country': 'us',
#    'localized_country_name': 'USA',
#    'distance': 11.471890670698762,
#    'city': 'Avon Lake',
#    'lon': -82.0199966430664,
#    'ranking': 39,
#    'id': 44012,
#    'state': 'OH',
#    'member_count': 130,
#    'lat': 41.4900016784668},
#   {'zip': '44236',
#    'country': 'us',
#    'localized_country_name': 'USA',
#    'distance': 23.12762468087753,
#    'city': 'Hudson',
#    'lon': -81.44000244140625,
#    'ranking': 40,
#    'id': 44236,
#    'state': 'OH',
#    'member_count': 127,
#    'lat': 41.25},
#   {'zip': '44001',
#    'country': 'us',
#    'localized_country_name': 'USA',
#    'distance': 23.21782572878043,
#    'city': 'Amherst',
#    'lon': -82.25,
#    'ranking': 41,
#    'id': 44001,
#    'state': 'OH',
#    'member_count': 122,
#    'lat': 41.369998931884766},
#   {'zip': '44685',
#    'country': 'us',
#    'localized_country_name': 'USA',
#    'distance': 39.50209010334484,
#    'city': 'Uniontown',
#    'lon': -81.38999938964844,
#    'ranking': 42,
#    'id': 44685,
#    'state': 'OH',
#    'member_count': 119,
#    'lat': 40.959999084472656},
#   {'zip': '44141',
#    'country': 'us',
#    'localized_country_name': 'USA',
#    'distance': 13.149914476566966,
#    'city': 'Brecksville',
#    'lon': -81.62000274658203,
#    'ranking': 43,
#    'id': 44141,
#    'state': 'OH',
#    'member_count': 118,
#    'lat': 41.310001373291016},
#   {'zip': '44281',
#    'country': 'us',
#    'localized_country_name': 'USA',
#    'distance': 28.314130630796,
#    'city': 'Wadsworth',
#    'lon': -81.7300033569336,
#    'ranking': 44,
#    'id': 44281,
#    'state': 'OH',
#    'member_count': 117,
#    'lat': 41.029998779296875},
#   {'zip': '44266',
#    'country': 'us',
#    'localized_country_name': 'USA',
#    'distance': 35.70218062329919,
#    'city': 'Ravenna',
#    'lon': -81.2300033569336,
#    'ranking': 45,
#    'id': 44266,
#    'state': 'OH',
#    'member_count': 116,
#    'lat': 41.15999984741211},
#   {'zip': '44147',
#    'country': 'us',
#    'localized_country_name': 'USA',
#    'distance': 10.461517162428104,
#    'city': 'Broadview Heights',
#    'lon': -81.68000030517578,
#    'ranking': 46,
#    'id': 44147,
#    'state': 'OH',
#    'member_count': 114,
#    'lat': 41.31999969482422},
#   {'zip': '44601',
#    'country': 'us',
#    'localized_country_name': 'USA',
#    'distance': 49.94223745979541,
#    'city': 'Alliance',
#    'lon': -81.13999938964844,
#    'ranking': 47,
#    'id': 44601,
#    'state': 'OH',
#    'member_count': 112,
#    'lat': 40.91999816894531},
#   {'zip': '44026',
#    'country': 'us',
#    'localized_country_name': 'USA',
#    'distance': 25.40551492139466,
#    'city': 'Chesterland',
#    'lon': -81.33999633789062,
#    'ranking': 48,
#    'id': 44026,
#    'state': 'OH',
#    'member_count': 105,
#    'lat': 41.540000915527344},
#   {'zip': '44142',
#    'country': 'us',
#    'localized_country_name': 'USA',
#    'distance': 2.6277588959650506,
#    'city': 'Brook Park',
#    'lon': -81.83000183105469,
#    'ranking': 49,
#    'id': 44142,
#    'state': 'OH',
#    'member_count': 96,
#    'lat': 41.400001525878906}],
#  'meta': {'next': 'https://api.meetup.com/2/cities?offset=1&sign=True&format=json&photo-host=public&page=50&radius=50&order=size&desc=false',
#   'method': 'Cities',
#   'total_count': 195,
#   'link': 'https://api.meetup.com/2/cities',
#   'count': 50,
#   'description': "Returns Meetup cities. This method supports search by latitude/longitude/radius, by country/state, by query term/zip, or a combination of all of these. Location-only searches by lat and lon return all cities within a radius of the provided coordinates. Searches with a query return up to 10 cities matching the term, and can be sorted by size or distance to a given coordinate. 'smart' ordering can be used to return the match(es) with the highest member_count, unless a smaller size match exists nearby the given coordinates. Query searches are supported for country but not country and state",
#   'lon': 'None',
#   'title': 'Cities',
#   'url': 'https://api.meetup.com/2/cities?offset=0&sign=True&format=json&photo-host=public&page=50&radius=50&order=size&desc=false',
#   'id': '',
#   'updated': 1263132772000,
#   'lat': 'None'}}

# %%
result1_df = pd.DataFrame(response1['results'])[['city', 'lat', 'lon', 'member_count', 'zip']]
result1_df = result1_df.set_index('city')
result1_df.head()
# Out:
#                  lat        lon  member_count    zip
# city
# Cleveland  41.490002 -81.669998         13715  44101
# Akron      41.040001 -81.519997          4700  44301
# Canton     40.730000 -81.449997          1830  44701
# Lakewood   41.480000 -81.790001          1002  44107
# Medina     41.130001 -81.860001           752  44256

# %%
mem_count = result1_df['member_count'].sum()
print(mem_count)
# Out:
# 32559

# %%
for zipCode in result1_df.zip:
    # Careful executing this call because the call is large and it takes a while, and we can run out of calls.
    group_url = 'https://api.meetup.com/find/groups?key=' + api_key + '&photo-host=public&zip=' + zipCode + '&page=1000000'
    
response2 = requests.get(group_url).json()
response2
# Out:
# [{'score': 1.0,
#   'id': 1603993,
#   'name': 'Northeast Ohio Hiking Club',
#   'status': 'active',
#   'link': 'https://www.meetup.com/NEOHiking/',
#   'urlname': 'NEOHiking',
#   'description': '<p>Hikers Unite! Short hikes, long hikes, easy hikes, moderate hikes, strenuous hikes, kid friendly hikes and dog friendly hikes! The mission is to provide a variety of hikes for hikers of all abilities to get together, enjoy nature and perhaps burn off a few calories in the process.</p>\n<p>\xa0</p>\n<p>All hikers\xa0participate\xa0at their own risk. Hiking should always be within your comfort and skill level. Please read the Meetup description carefully and email the event organizer if you have any question about your ability to complete the hike or other event. By signing up for a hike or other event you are stating that you are physically able to complete the event listed.\xa0\xa0You are responsible for your own safety and assume all risks and liabilities on all outings. Event organizers are unpaid volunteers and should not be relied upon to have any special skills or training.</p>\n<p>\xa0</p>\n<p>\xa0</p>',
#   'created': 1266952168000,
#   'city': 'Cleveland',
#   'untranslated_city': 'Cleveland',
#   'country': 'US',
#   'localized_country_name': 'USA',
#   'localized_location': 'Cleveland, OH',
#   'state': 'OH',
#   'join_mode': 'approval',
#   'visibility': 'public',
#   'lat': 41.38,
#   'lon': -81.79,
#   'members': 6091,
#   'organizer': {'id': 7034397,
#    'name': 'Liz B',
#    'bio': '',
#    'photo': {'id': 259100240,
#     'highres_link': 'https://secure.meetupstatic.com/photos/member/4/f/1/0/highres_259100240.jpeg',
#     'photo_link': 'https://secure.meetupstatic.com/photos/member/4/f/1/0/member_259100240.jpeg',
#     'thumb_link': 'https://secure.meetupstatic.com/photos/member/4/f/1/0/thumb_259100240.jpeg',
#     'type': 'member',
#     'base_url': 'https://secure.meetupstatic.com'}},
#   'who': 'Hikers',
#   'group_photo': {'id': 448512018,
#    'highres_link': 'https://secure.meetupstatic.com/photos/event/2/e/f/2/highres_448512018.jpeg',
#    'photo_link': 'https://secure.meetupstatic.com/photos/event/2/e/f/2/600_448512018.jpeg',
#    'thumb_link': 'https://secure.meetupstatic.com/photos/event/2/e/f/2/thumb_448512018.jpeg',
#    'type': 'event',
#    'base_url': 'https://secure.meetupstatic.com'},
#   'key_photo': {'id': 451963860,
#    'highres_link': 'https://secure.meetupstatic.com/photos/event/a/b/5/4/highres_451963860.jpeg',
#    'photo_link': 'https://secure.meetupstatic.com/photos/event/a/b/5/4/600_451963860.jpeg',
#    'thumb_link': 'https://secure.meetupstatic.com/photos/event/a/b/5/4/thumb_451963860.jpeg',
#    'type': 'event',
#    'base_url': 'https://secure.meetupstatic.com'},
#   'timezone': 'US/Eastern',
#   'next_event': {'id': 'cfwbfqyxmbxb',
#    'name': '3 Miles x 3 Miles Per Hr (3x3) Hike - Brecksville Leisure Hikes',
#    'yes_rsvp_count': 16,
#    'time': 1537308900000,
#    'utc_offset': -14400000},
#   'category': {'id': 23,
#    'name': 'Outdoors & Adventure',
#    'shortname': 'outdoors-adventure',
#    'sort_name': 'Outdoors & Adventure'},
#   'meta_category': {'id': 242,
#    'shortname': 'outdoors-adventure',
#    'name': 'Outdoors & Adventure',
#    'sort_name': 'Outdoors & Adventure',
#    'photo': {'id': 450131943,
#     'highres_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/7/highres_450131943.jpeg',
#     'photo_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/7/600_450131943.jpeg',
#     'thumb_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/7/thumb_450131943.jpeg',
#     'type': 'event',
#     'base_url': 'https://secure.meetupstatic.com'},
#    'category_ids': [3, 23]}},
#  {'score': 1.0,
#   'id': 1706881,
#   'name': 'Cleveland Big Data and Hadoop User Group',
#   'status': 'active',
#   'link': 'https://www.meetup.com/Cleveland-Hadoop/',
#   'urlname': 'Cleveland-Hadoop',
#   'description': '<p>The Cleveland Big Data and Hadoop User Group is for those interested in the distributed processing of large amounts of data, focusing heavily on the Hadoop stack.</p>\n<p>If you have more data than can comfortably fit on a single server and/or have a processing window that you can\'t meet processing with a single server, then you should come to our meetings!</p>\n<p>This group is industry agnostic and has a mix of classic user-group presentations (e.g., "I tried this out and here is what happened") as well as informative vendor sessions.</p>\n<p>Topics include networking, storage (e.g., HDFS, KeyValue storage like HBase), computation (e.g., MapReduce/YARN, graph processing), indexing/search (e.g., Solr), and analytics (e.g., Hive), data science, analytics, and others. <br></p>\n<p>If you have an interest in presenting, or have a topic you would like to see presented, contact Doug.</p>\n<p>For the history of the meetup read this:&nbsp; <br></p>\n<p><a href="http://themeildeal.blogspot.com/2016/08/how-to-create-successful-technical.html">http://themeildeal.blogspot.com/2016/08/how-to-create-successful-technical.html</a><br></p>',
#   'created': 1284494968000,
#   'city': 'Cleveland',
#   'untranslated_city': 'Cleveland',
#   'country': 'US',
#   'localized_country_name': 'USA',
#   'localized_location': 'Cleveland, OH',
#   'state': 'OH',
#   'join_mode': 'open',
#   'visibility': 'public',
#   'lat': 41.51,
#   'lon': -81.61,
#   'members': 2841,
#   'organizer': {'id': 12967608,
#    'name': 'Doug Meil',
#    'bio': '',
#    'photo': {'id': 254114519,
#     'highres_link': 'https://secure.meetupstatic.com/photos/member/3/8/b/7/highres_254114519.jpeg',
#     'photo_link': 'https://secure.meetupstatic.com/photos/member/3/8/b/7/member_254114519.jpeg',
#     'thumb_link': 'https://secure.meetupstatic.com/photos/member/3/8/b/7/thumb_254114519.jpeg',
#     'type': 'member',
#     'base_url': 'https://secure.meetupstatic.com'}},
#   'who': 'Super Hadoopers',
#   'group_photo': {'id': 17970143,
#    'highres_link': 'https://secure.meetupstatic.com/photos/event/7/5/b/f/highres_17970143.jpeg',
#    'photo_link': 'https://secure.meetupstatic.com/photos/event/7/5/b/f/600_17970143.jpeg',
#    'thumb_link': 'https://secure.meetupstatic.com/photos/event/7/5/b/f/thumb_17970143.jpeg',
#    'type': 'event',
#    'base_url': 'https://secure.meetupstatic.com'},
#   'key_photo': {'id': 464475286,
#    'highres_link': 'https://secure.meetupstatic.com/photos/event/3/b/b/6/highres_464475286.jpeg',
#    'photo_link': 'https://secure.meetupstatic.com/photos/event/3/b/b/6/600_464475286.jpeg',
#    'thumb_link': 'https://secure.meetupstatic.com/photos/event/3/b/b/6/thumb_464475286.jpeg',
#    'type': 'event',
#    'base_url': 'https://secure.meetupstatic.com'},
#   'timezone': 'US/Eastern',
#   'category': {'id': 34,
#    'name': 'Tech',
#    'shortname': 'tech',
#    'sort_name': 'Tech'},
#   'meta_category': {'id': 292,
#    'shortname': 'tech',
#    'name': 'Tech',
#    'sort_name': 'Tech',
#    'photo': {'id': 450131949,
#     'highres_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/d/highres_450131949.jpeg',
#     'photo_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/d/600_450131949.jpeg',
#     'thumb_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/d/thumb_450131949.jpeg',
#     'type': 'event',
#     'base_url': 'https://secure.meetupstatic.com'},
#    'category_ids': [34]}},
#  {'score': 1.0,
#   'id': 693119,
#   'name': 'The Cleveland 20s & 30s Group',
#   'status': 'active',
#   'link': 'https://www.meetup.com/CLE20s30s/',
#   'urlname': 'CLE20s30s',
#   'description': '<p>Welcome to The Cleveland 20s &amp; 30s Group! Meet other people near you! Picnics, potlucks, bars, live music, restaurants, parties, dances, outdoor activities, and much more! Our group has over 7,000 members and is still growing!</p>\n<p>Like us on Facebook at <a href="https://www.facebook.com/cleveland20s30s/" class="linkified">https://www.facebook.com/cleveland20s30s/</a></p>\n<p><a href="https://www.meetup.com/CLE20s30s/messages/boards/forum/22533228">Please read our member expectations before joining. These policies WILL BE enforced for the safety of our members. Attendance expectations and messaging people you don\'t know are the policies that get the most people removed. Please review them. </a>We are pro-actively getting rid of people in our group who show signs of creepy behavior. It\'s OK to be socially awkward. It isn\'t OK to be creepy. It isn\'t OK to ignore our policies because you don\'t agree with them. They have been put in place for the betterment of the quality of our group. We have a lot of experience running these types of groups and these policies have been put in place for a reason. If someone is creeping you out, tell David or Gayle (Organizers). <br></p>',
#   'created': 1190135836000,
#   'city': 'Cleveland',
#   'untranslated_city': 'Cleveland',
#   'country': 'US',
#   'localized_country_name': 'USA',
#   'localized_location': 'Cleveland, OH',
#   'state': 'OH',
#   'join_mode': 'approval',
#   'visibility': 'public_limited',
#   'lat': 41.51,
#   'lon': -81.68,
#   'members': 8414,
#   'organizer': {'id': 3680436,
#    'name': 'David',
#    'bio': "David's love for outdoor adventure most likely began at an early age, while being raised by wolves in northern Alaska. It was here where he learned to build fires and shelter using nothing but his bare hands and his young instinct...",
#    'photo': {'id': 137144542,
#     'highres_link': 'https://secure.meetupstatic.com/photos/member/a/d/f/e/highres_137144542.jpeg',
#     'photo_link': 'https://secure.meetupstatic.com/photos/member/a/d/f/e/member_137144542.jpeg',
#     'thumb_link': 'https://secure.meetupstatic.com/photos/member/a/d/f/e/thumb_137144542.jpeg',
#     'type': 'member',
#     'base_url': 'https://secure.meetupstatic.com'}},
#   'who': 'Members',
#   'group_photo': {'id': 460516411,
#    'highres_link': 'https://secure.meetupstatic.com/photos/event/4/0/1/b/highres_460516411.jpeg',
#    'photo_link': 'https://secure.meetupstatic.com/photos/event/4/0/1/b/600_460516411.jpeg',
#    'thumb_link': 'https://secure.meetupstatic.com/photos/event/4/0/1/b/thumb_460516411.jpeg',
#    'type': 'event',
#    'base_url': 'https://secure.meetupstatic.com'},
#   'key_photo': {'id': 460516986,
#    'highres_link': 'https://secure.meetupstatic.com/photos/event/4/2/5/a/highres_460516986.jpeg',
#    'photo_link': 'https://secure.meetupstatic.com/photos/event/4/2/5/a/600_460516986.jpeg',
#    'thumb_link': 'https://secure.meetupstatic.com/photos/event/4/2/5/a/thumb_460516986.jpeg',
#    'type': 'event',
#    'base_url': 'https://secure.meetupstatic.com'},
#   'timezone': 'US/Eastern',
#   'next_event': {'id': '254712952',
#    'name': 'Pickup Basketball',
#    'yes_rsvp_count': 3,
#    'time': 1537484400000,
#    'utc_offset': -14400000},
#   'category': {'id': 31,
#    'name': 'Socializing',
#    'shortname': 'socializing',
#    'sort_name': 'Socializing'},
#   'meta_category': {'id': 272,
#    'shortname': 'social',
#    'name': 'Social',
#    'sort_name': 'Social',
#    'photo': {'id': 450131947,
#     'highres_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/b/highres_450131947.jpeg',
#     'photo_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/b/600_450131947.jpeg',
#     'thumb_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/b/thumb_450131947.jpeg',
#     'type': 'event',
#     'base_url': 'https://secure.meetupstatic.com'},
#    'category_ids': [31]}},
#  {'score': 1.0,
#   'id': 1379910,
#   'name': 'The Happy Hour Group',
#   'status': 'active',
#   'link': 'https://www.meetup.com/The-Happy-Hour-Group/',
#   'urlname': 'The-Happy-Hour-Group',
#   'description': '<p>Make new friendships with people from east to west and take advantage of the great discounts being offered at many of the fine restaurants in Cleveland during happy hour. Happy Hours will be twice a month and alternate between the east and west side.</p>\n<p>From Wikipedia: <br>"Happy hour" is a marketing term for a period of time in which a restaurant or bar offers discounts on alcoholic drinks, such as beer, wine and cocktails.</p>\n<p>Typically, it is in the late afternoon Monday through Friday, usually taking place at some period between 4 PM and 7 PM. This promotion is intended to boost business on what may otherwise be a slow day. In most cases the "happy hour" lasts longer than a single hour.</p>\n<p>The term Happy Hour also is commonly used to describe the gathering of work colleagues at a restaurant or bar after work hours, possibly outside the period of 4 PM and 7 PM.</p>',
#   'created': 1234280583000,
#   'city': 'Cleveland',
#   'untranslated_city': 'Cleveland',
#   'country': 'US',
#   'localized_country_name': 'USA',
#   'localized_location': 'Cleveland, OH',
#   'state': 'OH',
#   'join_mode': 'approval',
#   'visibility': 'public',
#   'lat': 41.5,
#   'lon': -81.67,
#   'members': 5106,
#   'organizer': {'id': 6083768,
#    'name': 'Cheri',
#    'bio': '',
#    'photo': {'id': 11642847,
#     'highres_link': 'https://secure.meetupstatic.com/photos/member/b/1/f/highres_11642847.jpeg',
#     'photo_link': 'https://secure.meetupstatic.com/photos/member/b/1/f/member_11642847.jpeg',
#     'thumb_link': 'https://secure.meetupstatic.com/photos/member/b/1/f/thumb_11642847.jpeg',
#     'type': 'member',
#     'base_url': 'https://secure.meetupstatic.com'}},
#   'who': 'Men and women over 21',
#   'group_photo': {'id': 13337958,
#    'highres_link': 'https://secure.meetupstatic.com/photos/event/4/6/2/6/highres_13337958.jpeg',
#    'photo_link': 'https://secure.meetupstatic.com/photos/event/4/6/2/6/600_13337958.jpeg',
#    'thumb_link': 'https://secure.meetupstatic.com/photos/event/4/6/2/6/thumb_13337958.jpeg',
#    'type': 'event',
#    'base_url': 'https://secure.meetupstatic.com'},
#   'key_photo': {'id': 474578377,
#    'highres_link': 'https://secure.meetupstatic.com/photos/event/9/5/e/9/highres_474578377.jpeg',
#    'photo_link': 'https://secure.meetupstatic.com/photos/event/9/5/e/9/600_474578377.jpeg',
#    'thumb_link': 'https://secure.meetupstatic.com/photos/event/9/5/e/9/thumb_474578377.jpeg',
#    'type': 'event',
#    'base_url': 'https://secure.meetupstatic.com'},
#   'timezone': 'US/Eastern',
#   'next_event': {'id': '254612749',
#    'name': 'Happy Hour @ Vosh  on Oct 4 from 5 to 7 pm music starts 7 pm',
#    'yes_rsvp_count': 55,
#    'time': 1538686800000,
#    'utc_offset': -14400000},
#   'category': {'id': 10,
#    'name': 'Food & Drink',
#    'shortname': 'food-drink',
#    'sort_name': 'Food & Drink'},
#   'meta_category': {'id': 162,
#    'shortname': 'food',
#    'name': 'Food & Drink',
#    'sort_name': 'Food & Drink',
#    'photo': {'id': 450131937,
#     'highres_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/1/highres_450131937.jpeg',
#     'photo_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/1/600_450131937.jpeg',
#     'thumb_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/1/thumb_450131937.jpeg',
#     'type': 'event',
#     'base_url': 'https://secure.meetupstatic.com'},
#    'category_ids': [10]}},
#  {'score': 1.0,
#   'id': 18597533,
#   'name': "Life Is Short So Let's Have Some Fun Group!",
#   'status': 'active',
#   'link': 'https://www.meetup.com/Clevelands-Life-Is-Short/',
#   'urlname': 'Clevelands-Life-Is-Short',
#   'description': "<p>Life is too short to be anything but happy. Tomorrow is never guaranteed so lets get out and live a little. This group is for anyone who wants to get out and have fun and meet new people. Summer is approaching which means concerts, festivals, cookouts, drinks on the patio, anything outdoors. There isn't much we won't try at least once so feel free to make suggestions on meet up ideas. Join us and lets have some fun!</p>",
#   'created': 1431615105000,
#   'city': 'Cleveland',
#   'untranslated_city': 'Cleveland',
#   'country': 'US',
#   'localized_country_name': 'USA',
#   'localized_location': 'Cleveland, OH',
#   'state': 'OH',
#   'join_mode': 'open',
#   'visibility': 'public',
#   'lat': 41.48,
#   'lon': -81.69,
#   'members': 5159,
#   'organizer': {'id': 43998622,
#    'name': 'Edward',
#    'bio': '',
#    'photo': {'id': 258556119,
#     'highres_link': 'https://secure.meetupstatic.com/photos/member/3/e/f/7/highres_258556119.jpeg',
#     'photo_link': 'https://secure.meetupstatic.com/photos/member/3/e/f/7/member_258556119.jpeg',
#     'thumb_link': 'https://secure.meetupstatic.com/photos/member/3/e/f/7/thumb_258556119.jpeg',
#     'type': 'member',
#     'base_url': 'https://secure.meetupstatic.com'}},
#   'who': 'members',
#   'group_photo': {'id': 464349981,
#    'highres_link': 'https://secure.meetupstatic.com/photos/event/2/6/f/d/highres_464349981.jpeg',
#    'photo_link': 'https://secure.meetupstatic.com/photos/event/2/6/f/d/600_464349981.jpeg',
#    'thumb_link': 'https://secure.meetupstatic.com/photos/event/2/6/f/d/thumb_464349981.jpeg',
#    'type': 'event',
#    'base_url': 'https://secure.meetupstatic.com'},
#   'key_photo': {'id': 464133010,
#    'highres_link': 'https://secure.meetupstatic.com/photos/event/8/0/f/2/highres_464133010.jpeg',
#    'photo_link': 'https://secure.meetupstatic.com/photos/event/8/0/f/2/600_464133010.jpeg',
#    'thumb_link': 'https://secure.meetupstatic.com/photos/event/8/0/f/2/thumb_464133010.jpeg',
#    'type': 'event',
#    'base_url': 'https://secure.meetupstatic.com'},
#   'timezone': 'US/Eastern',
#   'next_event': {'id': '254529125',
#    'name': 'Cleveland Travel Meet-Up Social',
#    'yes_rsvp_count': 1,
#    'time': 1537311600000,
#    'utc_offset': -14400000},
#   'category': {'id': 31,
#    'name': 'Socializing',
#    'shortname': 'socializing',
#    'sort_name': 'Socializing'},
#   'meta_category': {'id': 272,
#    'shortname': 'social',
#    'name': 'Social',
#    'sort_name': 'Social',
#    'photo': {'id': 450131947,
#     'highres_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/b/highres_450131947.jpeg',
#     'photo_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/b/600_450131947.jpeg',
#     'thumb_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/b/thumb_450131947.jpeg',
#     'type': 'event',
#     'base_url': 'https://secure.meetupstatic.com'},
#    'category_ids': [31]}},
#  {'score': 1.0,
#   'id': 25616472,
#   'name': 'Cleveland Artificial Intelligence Group',
#   'status': 'active',
#   'link': 'https://www.meetup.com/Cleveland-Artificial-Intelligence-Group/',
#   'urlname': 'Cleveland-Artificial-Intelligence-Group',
#   'description': '<p>Check out our <a href="https://clevelandaigroup.github.io/">site</a>!&nbsp; It has links to everything else CAIG-related.<br></p>\n<p>Welcome to the Cleveland Artificial Intelligence Group! This is for anyone interested in artificial intelligence, including applications and research. Meetings will focus on a combination of introductory surveys, research walkthroughs, and paired programming events. Students and practitioners of all skill levels are welcome!</p>\n<p>Topics include classical AI, deep learning, natural language processing, computer vision, speech recognition, and reinforcement learning.</p>\n<p>If you have an interest in presenting, have a topic you would like to see presented, or would like to host a future meeting, contact Jason or file an issue on our <a href="https://github.com/ClevelandAIGroup/clevelandaigroup.github.io">Github repo</a>.</p>',
#   'created': 1503588053000,
#   'city': 'Cleveland',
#   'untranslated_city': 'Cleveland',
#   'country': 'US',
#   'localized_country_name': 'USA',
#   'localized_location': 'Cleveland, OH',
#   'state': 'OH',
#   'join_mode': 'open',
#   'visibility': 'public',
#   'lat': 41.49,
#   'lon': -81.67,
#   'members': 727,
#   'organizer': {'id': 199180381,
#    'name': 'Jason Mancuso',
#    'bio': '',
#    'photo': {'id': 272012527,
#     'highres_link': 'https://secure.meetupstatic.com/photos/member/7/f/0/f/highres_272012527.jpeg',
#     'photo_link': 'https://secure.meetupstatic.com/photos/member/7/f/0/f/member_272012527.jpeg',
#     'thumb_link': 'https://secure.meetupstatic.com/photos/member/7/f/0/f/thumb_272012527.jpeg',
#     'type': 'member',
#     'base_url': 'https://secure.meetupstatic.com'}},
#   'who': 'Humans',
#   'group_photo': {'id': 463980009,
#    'highres_link': 'https://secure.meetupstatic.com/photos/event/9/highres_463980009.jpeg',
#    'photo_link': 'https://secure.meetupstatic.com/photos/event/9/600_463980009.jpeg',
#    'thumb_link': 'https://secure.meetupstatic.com/photos/event/9/thumb_463980009.jpeg',
#    'type': 'event',
#    'base_url': 'https://secure.meetupstatic.com'},
#   'key_photo': {'id': 463980009,
#    'highres_link': 'https://secure.meetupstatic.com/photos/event/9/highres_463980009.jpeg',
#    'photo_link': 'https://secure.meetupstatic.com/photos/event/9/600_463980009.jpeg',
#    'thumb_link': 'https://secure.meetupstatic.com/photos/event/9/thumb_463980009.jpeg',
#    'type': 'event',
#    'base_url': 'https://secure.meetupstatic.com'},
#   'timezone': 'US/Eastern',
#   'next_event': {'id': '254314421',
#    'name': 'AI as Product, Graph Neural Networks, NLP @ remesh',
#    'yes_rsvp_count': 95,
#    'time': 1537477200000,
#    'utc_offset': -14400000},
#   'category': {'id': 34,
#    'name': 'Tech',
#    'shortname': 'tech',
#    'sort_name': 'Tech'},
#   'meta_category': {'id': 292,
#    'shortname': 'tech',
#    'name': 'Tech',
#    'sort_name': 'Tech',
#    'photo': {'id': 450131949,
#     'highres_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/d/highres_450131949.jpeg',
#     'photo_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/d/600_450131949.jpeg',
#     'thumb_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/d/thumb_450131949.jpeg',
#     'type': 'event',
#     'base_url': 'https://secure.meetupstatic.com'},
#    'category_ids': [34]}},
#  {'score': 1.0,
#   'id': 494930,
#   'name': 'nEo Adventurers',
#   'status': 'active',
#   'link': 'https://www.meetup.com/Northeast-Ohio-Adventurers/',
#   'urlname': 'Northeast-Ohio-Adventurers',
#   'description': '<p>Meet with people who like outdoor adventures and athletic activities, such as hiking, exploring, kayaking, bicycling, snowshoeing, bowling,&nbsp;etc. All are welcome!</p>\n<p><br></p>',
#   'created': 1178507477000,
#   'city': 'Cleveland',
#   'untranslated_city': 'Cleveland',
#   'country': 'US',
#   'localized_country_name': 'USA',
#   'localized_location': 'Cleveland, OH',
#   'state': 'OH',
#   'join_mode': 'open',
#   'visibility': 'public',
#   'lat': 41.52,
#   'lon': -81.56,
#   'members': 6084,
#   'organizer': {'id': 9021658,
#    'name': 'DickK',
#    'bio': 'I am a retired "shop" teacher. I work part time for Lake Metroparks in their Outdoor Ed. Dept. Love to read, play drums, do woodworking, cross county ski, snowshoe, & hike. Oh, and I love riding my recumbent trike.',
#    'photo': {'id': 249141410,
#     'highres_link': 'https://secure.meetupstatic.com/photos/member/5/3/a/2/highres_249141410.jpeg',
#     'photo_link': 'https://secure.meetupstatic.com/photos/member/5/3/a/2/member_249141410.jpeg',
#     'thumb_link': 'https://secure.meetupstatic.com/photos/member/5/3/a/2/thumb_249141410.jpeg',
#     'type': 'member',
#     'base_url': 'https://secure.meetupstatic.com'}},
#   'who': 'Adventurers',
#   'group_photo': {'id': 469862530,
#    'highres_link': 'https://secure.meetupstatic.com/photos/event/9/e/2/highres_469862530.jpeg',
#    'photo_link': 'https://secure.meetupstatic.com/photos/event/9/e/2/600_469862530.jpeg',
#    'thumb_link': 'https://secure.meetupstatic.com/photos/event/9/e/2/thumb_469862530.jpeg',
#    'type': 'event',
#    'base_url': 'https://secure.meetupstatic.com'},
#   'key_photo': {'id': 467049044,
#    'highres_link': 'https://secure.meetupstatic.com/photos/event/2/3/5/4/highres_467049044.jpeg',
#    'photo_link': 'https://secure.meetupstatic.com/photos/event/2/3/5/4/600_467049044.jpeg',
#    'thumb_link': 'https://secure.meetupstatic.com/photos/event/2/3/5/4/thumb_467049044.jpeg',
#    'type': 'event',
#    'base_url': 'https://secure.meetupstatic.com'},
#   'timezone': 'US/Eastern',
#   'next_event': {'id': 'wgtvrpyxmbxb',
#    'name': 'Bowling for Fun',
#    'yes_rsvp_count': 4,
#    'time': 1537309800000,
#    'utc_offset': -14400000},
#   'category': {'id': 23,
#    'name': 'Outdoors & Adventure',
#    'shortname': 'outdoors-adventure',
#    'sort_name': 'Outdoors & Adventure'},
#   'meta_category': {'id': 242,
#    'shortname': 'outdoors-adventure',
#    'name': 'Outdoors & Adventure',
#    'sort_name': 'Outdoors & Adventure',
#    'photo': {'id': 450131943,
#     'highres_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/7/highres_450131943.jpeg',
#     'photo_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/7/600_450131943.jpeg',
#     'thumb_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/7/thumb_450131943.jpeg',
#     'type': 'event',
#     'base_url': 'https://secure.meetupstatic.com'},
#    'category_ids': [3, 23]}},
#  {'score': 1.0,
#   'id': 1721176,
#   'name': 'LaunchHouse',
#   'status': 'active',
#   'link': 'https://www.meetup.com/LaunchHouse/',
#   'urlname': 'LaunchHouse',
#   'description': '<p>LaunchHouse is a coworking community where businesses and people come to grow.&nbsp;<span>We are entrepreneurs, freelancers, startups, solopreneurs, designers, consultants, and anyone who doesn’t fit into a neat corporate box. &nbsp;LaunchHouse is the place for people to engage with and learn from one another while developing their businesses.</span></p>\n<p>Follow us on Facebook:&nbsp;<a href="http://www.facebook.com/LaunchHouse">http://www.facebook.com/LaunchHouse</a></p>\n<p>Follow us on Twitter:&nbsp;<a href="https://twitter.com/LaunchHouse">https://twitter.com/LaunchHouse</a></p>\n<p><a href="http://www.linkedin.com/companies/266814/"></a></p>\n<p>Follow us on Instagram:&nbsp;<a href="https://www.instagram.com/launchhouse/">https://www.instagram.com/launchhouse/</a></p>\n<p>Follow us on&nbsp;LinkedIn:&nbsp;<a href="https://www.linkedin.com/company/launchhouse">https://www.linkedin.com/company/launchhouse</a></p>\n<p><br></p>\n<p><br></p>\n<p><br></p>',
#   'created': 1286937513000,
#   'city': 'Cleveland',
#   'untranslated_city': 'Cleveland',
#   'country': 'US',
#   'localized_country_name': 'USA',
#   'localized_location': 'Cleveland, OH',
#   'state': 'OH',
#   'join_mode': 'open',
#   'visibility': 'public',
#   'lat': 41.56,
#   'lon': -81.48,
#   'members': 2177,
#   'organizer': {'id': 13425806,
#    'name': 'Todd Goldstein',
#    'bio': '',
#    'photo': {'id': 11314798,
#     'photo_link': 'https://secure.meetupstatic.com/photos/member/8/7/e/e/member_11314798.jpeg',
#     'thumb_link': 'https://secure.meetupstatic.com/photos/member/8/7/e/e/thumb_11314798.jpeg',
#     'type': 'member',
#     'base_url': 'https://secure.meetupstatic.com'}},
#   'who': 'Community Members',
#   'group_photo': {'id': 459593831,
#    'highres_link': 'https://secure.meetupstatic.com/photos/event/d/2/4/7/highres_459593831.jpeg',
#    'photo_link': 'https://secure.meetupstatic.com/photos/event/d/2/4/7/600_459593831.jpeg',
#    'thumb_link': 'https://secure.meetupstatic.com/photos/event/d/2/4/7/thumb_459593831.jpeg',
#    'type': 'event',
#    'base_url': 'https://secure.meetupstatic.com'},
#   'key_photo': {'id': 471340059,
#    'highres_link': 'https://secure.meetupstatic.com/photos/event/9/c/7/b/highres_471340059.jpeg',
#    'photo_link': 'https://secure.meetupstatic.com/photos/event/9/c/7/b/600_471340059.jpeg',
#    'thumb_link': 'https://secure.meetupstatic.com/photos/event/9/c/7/b/thumb_471340059.jpeg',
#    'type': 'event',
#    'base_url': 'https://secure.meetupstatic.com'},
#   'timezone': 'US/Eastern',
#   'next_event': {'id': '254283745',
#    'name': 'How to Brand Your Business Part 1: Brand Identity',
#    'yes_rsvp_count': 4,
#    'time': 1537394400000,
#    'utc_offset': -14400000},
#   'category': {'id': 2,
#    'name': 'Career & Business',
#    'shortname': 'career-business',
#    'sort_name': 'Career & Business'},
#   'meta_category': {'id': 522,
#    'shortname': 'career-business',
#    'name': 'Career & Business',
#    'sort_name': 'Career & Business',
#    'photo': {'id': 450131927,
#     'highres_link': 'https://secure.meetupstatic.com/photos/event/2/e/9/7/highres_450131927.jpeg',
#     'photo_link': 'https://secure.meetupstatic.com/photos/event/2/e/9/7/600_450131927.jpeg',
#     'thumb_link': 'https://secure.meetupstatic.com/photos/event/2/e/9/7/thumb_450131927.jpeg',
#     'type': 'event',
#     'base_url': 'https://secure.meetupstatic.com'},
#    'category_ids': [2]}},
#  {'score': 1.0,
#   'id': 1277331,
#   'name': 'North East Ohio (NEO) 45 yrs & Over Social Singles.',
#   'status': 'active',
#   'link': 'https://www.meetup.com/NEO-45-yrs-and-Over-Social-Singles/',
#   'urlname': 'NEO-45-yrs-and-Over-Social-Singles',
#   'description': "<p><span>Need to get out more? Want to meet people/friends and stay active? &nbsp;We service the Summit, Portage , Cuyahoga County, and surrounding areas for singles 45 and over. &nbsp;Come join us.&nbsp;This group is for those of us who want to get out of the house and have some fun but don't want to go out alone.</span></p>\n<p><strong><em>1.) As the group continues to grow with new members,&nbsp;we ask that you post&nbsp; a recognizable picture and an accurate first name on your profile within a week of joining, &nbsp;(Last name not required) &nbsp;so we&nbsp;know who you are when you attend a meetup function.</em></strong> <br></p>\n<p><span><span><strong><span><em>2. Please be courteous about your&nbsp;RSVP's for events.&nbsp; If you RSVP to a meetup event &nbsp;and are a no show 3 times, you will automatically be&nbsp;dropped from the group.</em></span></strong></span></span></p>\n<p><span><span><strong><span><em>3.</em></span></strong></span></span> <span><span><span><strong><span><em>** Events are for socializing and friendship.**</em></span></strong></span></span></span></p>\n<p><span><span><span><strong><span><em>4. &nbsp;Meetup code of conduct says Bullying, harassment, exploitation, and acts of hate undermine community building in safe spaces where people can trust one another. Building real relationships requires us to be more compassionate and kinder towards one another. &nbsp;Meetup enforces against behaviors that are threatening, intentionally malicious, or personally harmful--physically, emotionally, or mentally. We must keep our members safe and feeling safe at our events.</em></span></strong></span></span></span></p>\n<p><strong><em>TREAT OTHERS WITH RESPECT AND&nbsp; OTHERS WILL RESPECT YOU.</em></strong><br></p>\n<p><span><span><span><strong><span><em> <br></em></span></strong></span></span></span></p>",
#   'created': 1220796247000,
#   'city': 'Kent',
#   'untranslated_city': 'Kent',
#   'country': 'US',
#   'localized_country_name': 'USA',
#   'localized_location': 'Kent, OH',
#   'state': 'OH',
#   'join_mode': 'open',
#   'visibility': 'public',
#   'lat': 41.15,
#   'lon': -81.33,
#   'members': 3163,
#   'organizer': {'id': 12113513,
#    'name': 'Mary',
#    'bio': 'I am a divorced female looking to widen my horizons  with new friends and activities.  Have 2 grown children, and one grandchild.   Enjoy music,  traveling, wine tasting, dining out, sports, and good people.',
#    'photo': {'id': 9718095,
#     'highres_link': 'https://secure.meetupstatic.com/photos/member/e/2/e/f/highres_9718095.jpeg',
#     'photo_link': 'https://secure.meetupstatic.com/photos/member/e/2/e/f/member_9718095.jpeg',
#     'thumb_link': 'https://secure.meetupstatic.com/photos/member/e/2/e/f/thumb_9718095.jpeg',
#     'type': 'member',
#     'base_url': 'https://secure.meetupstatic.com'}},
#   'who': 'Friends',
#   'group_photo': {'id': 464746940,
#    'highres_link': 'https://secure.meetupstatic.com/photos/event/b/7/5/c/highres_464746940.jpeg',
#    'photo_link': 'https://secure.meetupstatic.com/photos/event/b/7/5/c/600_464746940.jpeg',
#    'thumb_link': 'https://secure.meetupstatic.com/photos/event/b/7/5/c/thumb_464746940.jpeg',
#    'type': 'event',
#    'base_url': 'https://secure.meetupstatic.com'},
#   'key_photo': {'id': 472325466,
#    'highres_link': 'https://secure.meetupstatic.com/photos/event/1/5/5/a/highres_472325466.jpeg',
#    'photo_link': 'https://secure.meetupstatic.com/photos/event/1/5/5/a/600_472325466.jpeg',
#    'thumb_link': 'https://secure.meetupstatic.com/photos/event/1/5/5/a/thumb_472325466.jpeg',
#    'type': 'event',
#    'base_url': 'https://secure.meetupstatic.com'},
#   'timezone': 'US/Eastern',
#   'next_event': {'id': '251998288',
#    'name': 'Happy Hour at Lager and Vine Gastropub and Wine Bar, Hudson   !!',
#    'yes_rsvp_count': 39,
#    'time': 1537642800000,
#    'utc_offset': -14400000},
#   'category': {'id': 31,
#    'name': 'Socializing',
#    'shortname': 'socializing',
#    'sort_name': 'Socializing'},
#   'meta_category': {'id': 272,
#    'shortname': 'social',
#    'name': 'Social',
#    'sort_name': 'Social',
#    'photo': {'id': 450131947,
#     'highres_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/b/highres_450131947.jpeg',
#     'photo_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/b/600_450131947.jpeg',
#     'thumb_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/b/thumb_450131947.jpeg',
#     'type': 'event',
#     'base_url': 'https://secure.meetupstatic.com'},
#    'category_ids': [31]}},
#  {'score': 1.0,
#   'id': 20761026,
#   'name': 'Cleveland Girls Just Wanna Have Fun!',
#   'status': 'active',
#   'link': 'https://www.meetup.com/Cleveland-Girls-Just-Wanna-Have-Fun/',
#   'urlname': 'Cleveland-Girls-Just-Wanna-Have-Fun',
#   'description': "<p><span>Are you looking to make friends with some awesome new girls while going to new happy hours, brunches, restaurants, theater shows, and movies?&nbsp;&nbsp;</span><span>Do you want to cross things off your bucket list, and experience all the great things Cleveland has to offer?&nbsp;&nbsp;</span><span>From concerts to ziplining, dining out to day trips and everything in between... that's what Girls Just Wanna Have Fun is all about!!!</span><br></p>\n<p><span>This group has recently decided to require dues of the members to help with our fees.&nbsp; All extra money collected will be used for things like birthday presents for our monthly dinners, printouts for various events, plates and utensils, turkey for Friendsgiving, prizes for our Christmas party, etc.</span></p>\n<p><span>*** PLEASE NOTE: We will only approve members who have a personal photo of themselves posted due to previous problems. Sorry for any inconvenience. Also, three no shows will be cause for removal from the group. A lot of time and effort go into the preparation for this, and as a courtesy, please just change your RSVP or let the planner know if you can't make it.<br></span></p>",
#   'created': 1476656877000,
#   'city': 'Cleveland',
#   'untranslated_city': 'Cleveland',
#   'country': 'US',
#   'localized_country_name': 'USA',
#   'localized_location': 'Cleveland, OH',
#   'state': 'OH',
#   'join_mode': 'approval',
#   'visibility': 'public_limited',
#   'lat': 41.49,
#   'lon': -81.67,
#   'members': 302,
#   'organizer': {'id': 31983092,
#    'name': 'Kristen Fitzhugh',
#    'bio': '',
#    'photo': {'id': 276264284,
#     'highres_link': 'https://secure.meetupstatic.com/photos/member/5/e/d/c/highres_276264284.jpeg',
#     'photo_link': 'https://secure.meetupstatic.com/photos/member/5/e/d/c/member_276264284.jpeg',
#     'thumb_link': 'https://secure.meetupstatic.com/photos/member/5/e/d/c/thumb_276264284.jpeg',
#     'type': 'member',
#     'base_url': 'https://secure.meetupstatic.com'}},
#   'who': 'CLE Girls',
#   'key_photo': {'id': 471135604,
#    'highres_link': 'https://secure.meetupstatic.com/photos/event/3/c/f/4/highres_471135604.jpeg',
#    'photo_link': 'https://secure.meetupstatic.com/photos/event/3/c/f/4/600_471135604.jpeg',
#    'thumb_link': 'https://secure.meetupstatic.com/photos/event/3/c/f/4/thumb_471135604.jpeg',
#    'type': 'event',
#    'base_url': 'https://secure.meetupstatic.com'},
#   'timezone': 'US/Eastern',
#   'next_event': {'id': '250960167',
#    'name': 'Book Club- The Power by Naomi Alderman',
#    'yes_rsvp_count': 18,
#    'time': 1537311600000,
#    'utc_offset': -14400000},
#   'category': {'id': 31,
#    'name': 'Socializing',
#    'shortname': 'socializing',
#    'sort_name': 'Socializing'},
#   'meta_category': {'id': 272,
#    'shortname': 'social',
#    'name': 'Social',
#    'sort_name': 'Social',
#    'photo': {'id': 450131947,
#     'highres_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/b/highres_450131947.jpeg',
#     'photo_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/b/600_450131947.jpeg',
#     'thumb_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/b/thumb_450131947.jpeg',
#     'type': 'event',
#     'base_url': 'https://secure.meetupstatic.com'},
#    'category_ids': [31]}},
#  {'score': 1.0,
#   'id': 4594432,
#   'name': 'Summit County Ohio Hikers',
#   'status': 'active',
#   'link': 'https://www.meetup.com/summit_county_ohio_hikers/',
#   'urlname': 'summit_county_ohio_hikers',
#   'description': '<p>We hike between three and six miles and the pace is between 2.5 and 3.0 miles per hour which is perfect for a beginner or intermediate hiker.&nbsp;</p>\n<p>Some hikes are in the woods. Some hikes are with dogs. Some are strictly fitness hikes designed to get 10,000 steps or more in your day.&nbsp;</p>',
#   'created': 1345480898000,
#   'city': 'Akron',
#   'untranslated_city': 'Akron',
#   'country': 'US',
#   'localized_country_name': 'USA',
#   'localized_location': 'Akron, OH',
#   'state': 'OH',
#   'join_mode': 'open',
#   'visibility': 'public',
#   'lat': 41.08,
#   'lon': -81.52,
#   'members': 2629,
#   'organizer': {'id': 15036381,
#    'name': 'Dede',
#    'bio': 'I enjoy meeting new people and being active. Hiking and biking are of great interest to me. Love to laugh!',
#    'photo': {'id': 278801336,
#     'highres_link': 'https://secure.meetupstatic.com/photos/member/a/1/7/8/highres_278801336.jpeg',
#     'photo_link': 'https://secure.meetupstatic.com/photos/member/a/1/7/8/member_278801336.jpeg',
#     'thumb_link': 'https://secure.meetupstatic.com/photos/member/a/1/7/8/thumb_278801336.jpeg',
#     'type': 'member',
#     'base_url': 'https://secure.meetupstatic.com'}},
#   'who': 'Hikers',
#   'group_photo': {'id': 186500842,
#    'highres_link': 'https://secure.meetupstatic.com/photos/event/5/1/6/a/highres_186500842.jpeg',
#    'photo_link': 'https://secure.meetupstatic.com/photos/event/5/1/6/a/600_186500842.jpeg',
#    'thumb_link': 'https://secure.meetupstatic.com/photos/event/5/1/6/a/thumb_186500842.jpeg',
#    'type': 'event',
#    'base_url': 'https://secure.meetupstatic.com'},
#   'key_photo': {'id': 466621412,
#    'highres_link': 'https://secure.meetupstatic.com/photos/event/5/8/4/highres_466621412.jpeg',
#    'photo_link': 'https://secure.meetupstatic.com/photos/event/5/8/4/600_466621412.jpeg',
#    'thumb_link': 'https://secure.meetupstatic.com/photos/event/5/8/4/thumb_466621412.jpeg',
#    'type': 'event',
#    'base_url': 'https://secure.meetupstatic.com'},
#   'timezone': 'US/Eastern',
#   'next_event': {'id': '254553411',
#    'name': "Let's hike the Wetmore Bridle trail in the CVNP !",
#    'yes_rsvp_count': 6,
#    'time': 1537309800000,
#    'utc_offset': -14400000},
#   'category': {'id': 9,
#    'name': 'Fitness',
#    'shortname': 'fitness',
#    'sort_name': 'Fitness'},
#   'meta_category': {'id': 282,
#    'shortname': 'sports-fitness',
#    'name': 'Sports & Fitness',
#    'sort_name': 'Sports & Fitness',
#    'photo': {'id': 450131948,
#     'highres_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/c/highres_450131948.jpeg',
#     'photo_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/c/600_450131948.jpeg',
#     'thumb_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/c/thumb_450131948.jpeg',
#     'type': 'event',
#     'base_url': 'https://secure.meetupstatic.com'},
#    'category_ids': [9, 32]}},
#  {'score': 1.0,
#   'id': 22788985,
#   'name': 'Crypto Cleveland',
#   'status': 'active',
#   'link': 'https://www.meetup.com/Crypto-Cleveland/',
#   'urlname': 'Crypto-Cleveland',
#   'description': "<p>If you're interested in exploring the paradigm shift that is trustless, decentralized, public blockchain-based cryptocurrency-and-beyond systems, come meditate with us on deep thought.</p>\n<p>If that sounds like a bit too much, we can start small and lay down the framework for understanding the awesome potential that the systems like these contain.</p>\n<p>We hope to spread knowledge and thought through open discussion and education.</p>",
#   'created': 1488774707000,
#   'city': 'Cleveland',
#   'untranslated_city': 'Cleveland',
#   'country': 'US',
#   'localized_country_name': 'USA',
#   'localized_location': 'Cleveland, OH',
#   'state': 'OH',
#   'join_mode': 'open',
#   'visibility': 'public',
#   'lat': 41.49,
#   'lon': -81.67,
#   'members': 825,
#   'organizer': {'id': 223088521,
#    'name': 'Adam Gall',
#    'bio': '',
#    'photo': {'id': 270583353,
#     'highres_link': 'https://secure.meetupstatic.com/photos/member/a/9/5/9/highres_270583353.jpeg',
#     'photo_link': 'https://secure.meetupstatic.com/photos/member/a/9/5/9/member_270583353.jpeg',
#     'thumb_link': 'https://secure.meetupstatic.com/photos/member/a/9/5/9/thumb_270583353.jpeg',
#     'type': 'member',
#     'base_url': 'https://secure.meetupstatic.com'}},
#   'who': 'Cryptonauts',
#   'key_photo': {'id': 467441065,
#    'highres_link': 'https://secure.meetupstatic.com/photos/event/a/0/6/9/highres_467441065.jpeg',
#    'photo_link': 'https://secure.meetupstatic.com/photos/event/a/0/6/9/600_467441065.jpeg',
#    'thumb_link': 'https://secure.meetupstatic.com/photos/event/a/0/6/9/thumb_467441065.jpeg',
#    'type': 'event',
#    'base_url': 'https://secure.meetupstatic.com'},
#   'timezone': 'US/Eastern',
#   'next_event': {'id': 'pfssdqyxmbhc',
#    'name': 'Bagels & Blockchain @ Foyer Cafe',
#    'yes_rsvp_count': 10,
#    'time': 1537873200000,
#    'utc_offset': -14400000},
#   'category': {'id': 34,
#    'name': 'Tech',
#    'shortname': 'tech',
#    'sort_name': 'Tech'},
#   'meta_category': {'id': 292,
#    'shortname': 'tech',
#    'name': 'Tech',
#    'sort_name': 'Tech',
#    'photo': {'id': 450131949,
#     'highres_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/d/highres_450131949.jpeg',
#     'photo_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/d/600_450131949.jpeg',
#     'thumb_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/d/thumb_450131949.jpeg',
#     'type': 'event',
#     'base_url': 'https://secure.meetupstatic.com'},
#    'category_ids': [34]}},
#  {'score': 1.0,
#   'id': 22205996,
#   'name': 'Greater Stark Over 40 Social Group',
#   'status': 'active',
#   'link': 'https://www.meetup.com/Greater-Stark-Over-40-Social-Group/',
#   'urlname': 'Greater-Stark-Over-40-Social-Group',
#   'description': '<p>This group is for anyone over 40 that wants to get out and socialize - mingle and meet new people - in a group with other people of similar age. We schedule regular social events that are fun and relaxing with a focus on social interaction - laughing, talking, eating, drinking, listening to music and dancing. Events are primarily located in Stark County and the surrounding areas including Wayne, Tuscarawas, Carroll, Columbiana, Mahoning, and Portage Counties. Everyone is welcome no matter where you live.</p>\n<p>Please join us! We are a very friendly and welcoming group. If you have any questions or concerns, please feel free to contact one of the organizers.</p>\n<p>Please post a recognizable picture; this makes it much easier to get to know (and remember) each other. If you are uncomfortable with this, please message me so I know you are not a robot or a creep. We try to provide a safe environment for socializing.&nbsp; We also wear name tags at events to facilitate socializing: if you see someone wearing a nametag, you know they are there to socialize and it is safe to go up and talk to them.&nbsp;</p>\n<p>Events are for socializing and friendship. This is not a dating site. No one should ever feel pressured in any way to provide their phone number, accept a date, consume alcohol, dance, or anything else they are not comfortable with.</p>\n<p>The group is geared toward people who do not have someone to socialize with, regardless of relationship status: Some people are not \'single\' but, for a variety of reasons, do not have someone to socialize with. </p>\n<p>While couples are allowed, it is important that each person is open to mingling and socializing with others, and also that their partner is OK with it.&nbsp; Couples that socialize only as a couple tend to put a damper on group socializing and send the wrong message: Someone that is "looking" will think "My chances of finding someone tonight are high" and that is <b>not</b> what the group is about!&nbsp; And someone that is "not looking" will be discouraged and think they do not belong - while that is specifically who the group is for.&nbsp; If your intent is to stick with your partner during the majority of the event, then this group really isn\'t for you.</p>\n<p> If you have a suggestion for an event, please let us know! </p>',
#   'created': 1486065099000,
#   'city': 'North Canton',
#   'untranslated_city': 'North Canton',
#   'country': 'US',
#   'localized_country_name': 'USA',
#   'localized_location': 'North Canton, OH',
#   'state': 'OH',
#   'join_mode': 'open',
#   'visibility': 'public',
#   'lat': 40.9,
#   'lon': -81.43,
#   'members': 1112,
#   'organizer': {'id': 44329422,
#    'name': 'BobR',
#    'bio': 'I am having the best times of my life with the best friends in the whole world right here in my local meetup groups.',
#    'photo': {'id': 278861925,
#     'highres_link': 'https://secure.meetupstatic.com/photos/member/a/3/c/5/highres_278861925.jpeg',
#     'photo_link': 'https://secure.meetupstatic.com/photos/member/a/3/c/5/member_278861925.jpeg',
#     'thumb_link': 'https://secure.meetupstatic.com/photos/member/a/3/c/5/thumb_278861925.jpeg',
#     'type': 'member',
#     'base_url': 'https://secure.meetupstatic.com'}},
#   'who': 'Meetup friends',
#   'group_photo': {'id': 458038645,
#    'highres_link': 'https://secure.meetupstatic.com/photos/event/e/5/1/5/highres_458038645.jpeg',
#    'photo_link': 'https://secure.meetupstatic.com/photos/event/e/5/1/5/600_458038645.jpeg',
#    'thumb_link': 'https://secure.meetupstatic.com/photos/event/e/5/1/5/thumb_458038645.jpeg',
#    'type': 'event',
#    'base_url': 'https://secure.meetupstatic.com'},
#   'key_photo': {'id': 458035607,
#    'highres_link': 'https://secure.meetupstatic.com/photos/event/d/9/3/7/highres_458035607.jpeg',
#    'photo_link': 'https://secure.meetupstatic.com/photos/event/d/9/3/7/600_458035607.jpeg',
#    'thumb_link': 'https://secure.meetupstatic.com/photos/event/d/9/3/7/thumb_458035607.jpeg',
#    'type': 'event',
#    'base_url': 'https://secure.meetupstatic.com'},
#   'timezone': 'US/Eastern',
#   'next_event': {'id': '254211711',
#    'name': '"My Friend Jack" back at the Towpath Cabinn!!',
#    'yes_rsvp_count': 20,
#    'time': 1537657200000,
#    'utc_offset': -14400000},
#   'category': {'id': 31,
#    'name': 'Socializing',
#    'shortname': 'socializing',
#    'sort_name': 'Socializing'},
#   'meta_category': {'id': 272,
#    'shortname': 'social',
#    'name': 'Social',
#    'sort_name': 'Social',
#    'photo': {'id': 450131947,
#     'highres_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/b/highres_450131947.jpeg',
#     'photo_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/b/600_450131947.jpeg',
#     'thumb_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/b/thumb_450131947.jpeg',
#     'type': 'event',
#     'base_url': 'https://secure.meetupstatic.com'},
#    'category_ids': [31]}},
#  {'score': 1.0,
#   'id': 18755762,
#   'name': 'Northeastern Ohio Toastmasters - District 10',
#   'status': 'active',
#   'link': 'https://www.meetup.com/Northeastern-Ohio-Toastmasters/',
#   'urlname': 'Northeastern-Ohio-Toastmasters',
#   'description': "<p>If you're interested in learning public speaking skills or leadership skills, Toastmasters is for you. This proven program allows each member to work at a self-determined pace to master the art of public speaking. If you communicate with others, you will be seen as a leader. If you want to be a leader, you must be able to communicate well and effectively. Toastmasters teaches both with ample opportunities to give speeches to supportive members and take on leadership roles in the local club and in the district.</p>",
#   'created': 1437437222000,
#   'city': 'Cleveland',
#   'untranslated_city': 'Cleveland',
#   'country': 'US',
#   'localized_country_name': 'USA',
#   'localized_location': 'Cleveland, OH',
#   'state': 'OH',
#   'join_mode': 'open',
#   'visibility': 'public',
#   'lat': 41.49,
#   'lon': -81.67,
#   'members': 1210,
#   'organizer': {'id': 185595203,
#    'name': 'dave wiley',
#    'bio': '',
#    'photo': {'id': 257548202,
# ...
#    'yes_rsvp_count': 7,
#    'time': 1540076400000,
#    'utc_offset': -14400000},
#   'category': {'id': 5,
#    'name': 'Dancing',
#    'shortname': 'dancing',
#    'sort_name': 'Dancing'},
#   'meta_category': {'id': 542,
#    'shortname': 'dancing',
#    'name': 'Dance',
#    'sort_name': 'Dance',
#    'photo': {'id': 450131930,
#     'highres_link': 'https://secure.meetupstatic.com/photos/event/2/e/9/a/highres_450131930.jpeg',
#     'photo_link': 'https://secure.meetupstatic.com/photos/event/2/e/9/a/600_450131930.jpeg',
#     'thumb_link': 'https://secure.meetupstatic.com/photos/event/2/e/9/a/thumb_450131930.jpeg',
#     'type': 'event',
#     'base_url': 'https://secure.meetupstatic.com'},
#    'category_ids': [5]}},
#  {'score': 1.0,
#   'id': 3375922,
#   'name': 'IAA-Cleveland Center',
#   'status': 'active',
#   'link': 'https://www.meetup.com/IAA-Astrology-Cleveland/',
#   'urlname': 'IAA-Astrology-Cleveland',
#   'description': "<p>The IAA-Cleveland Center is basically astrological, but we're an informal group who is willing to explore.</p>\n<p>I, Ena Stanley (Organizer), founded an astrological Internet school in 1997, but when I moved to the Cleveland area in 2011, I found this perfect place to open a small center in Westlake. The Center is right off I-90...You get off at the Columbia-South exit, go to that 1st light (not even a block), turn west and we're the big white house immediately next to the Regency Centre driveway. There's parking all around: across the street at Canterbury Square, and down the Regency Centre driveway to the parking lot. Just come to the front of the house, through the front door and upstairs to the 2nd floor.<br></p>\n<p>We are holding all sorts of social events, as well as classes and workshops for those of you who want to explore and learn a variety of topics to deepen your knowledge and understanding. Since we are always looking for ways that will help us empower ourselves, we will explore all alternatives. Here at the Center we hope to bring you speakers with their topics in astrology, but as well we want to bring you authorities in other venues who can share their knowledge of self-discovery, enlightenment and healing.<br></p>\n<p>We look forward to meeting each of you so together we can create a group in love and light!<br></p>",
#   'created': 1330370047000,
#   'city': 'Westlake',
#   'untranslated_city': 'Westlake',
#   'country': 'US',
#   'localized_country_name': 'USA',
#   'localized_location': 'Westlake, OH',
#   'state': 'OH',
#   'join_mode': 'open',
#   'visibility': 'public',
#   'lat': 41.45,
#   'lon': -81.93,
#   'members': 380,
#   'organizer': {'id': 39687062,
#    'name': 'Ena Stanley',
#    'bio': "Ena Stanley is the winner of the 2012 Marion D. March Regulus Award for Education and was the 1st to receive NCGR's Level IV Certification in the field of education. She is the President and Founder  of the International Academy of Astrology.",
#    'photo': {'id': 273733676,
#     'highres_link': 'https://secure.meetupstatic.com/photos/member/3/5/6/c/highres_273733676.jpeg',
#     'photo_link': 'https://secure.meetupstatic.com/photos/member/3/5/6/c/member_273733676.jpeg',
#     'thumb_link': 'https://secure.meetupstatic.com/photos/member/3/5/6/c/thumb_273733676.jpeg',
#     'type': 'member',
#     'base_url': 'https://secure.meetupstatic.com'}},
#   'who': 'Friends of Metaphysics',
#   'group_photo': {'id': 97258692,
#    'highres_link': 'https://secure.meetupstatic.com/photos/event/e/5/4/4/highres_97258692.jpeg',
#    'photo_link': 'https://secure.meetupstatic.com/photos/event/e/5/4/4/600_97258692.jpeg',
#    'thumb_link': 'https://secure.meetupstatic.com/photos/event/e/5/4/4/thumb_97258692.jpeg',
#    'type': 'event',
#    'base_url': 'https://secure.meetupstatic.com'},
#   'key_photo': {'id': 469301092,
#    'highres_link': 'https://secure.meetupstatic.com/photos/event/a/0/8/4/highres_469301092.jpeg',
#    'photo_link': 'https://secure.meetupstatic.com/photos/event/a/0/8/4/600_469301092.jpeg',
#    'thumb_link': 'https://secure.meetupstatic.com/photos/event/a/0/8/4/thumb_469301092.jpeg',
#    'type': 'event',
#    'base_url': 'https://secure.meetupstatic.com'},
#   'timezone': 'US/Eastern',
#   'next_event': {'id': 'fmvdxpyxmbbc',
#    'name': 'Astrology Made Easy - An 8-Week Course with Eva Starr',
#    'yes_rsvp_count': 2,
#    'time': 1537484400000,
#    'utc_offset': -14400000},
#   'category': {'id': 22,
#    'name': 'New Age & Spirituality',
#    'shortname': 'new-age-spirituality',
#    'sort_name': 'New Age & Spirituality'},
#   'meta_category': {'id': 132,
#    'shortname': 'beliefs',
#    'name': 'Beliefs',
#    'sort_name': 'Beliefs',
#    'photo': {'id': 450131925,
#     'highres_link': 'https://secure.meetupstatic.com/photos/event/2/e/9/5/highres_450131925.jpeg',
#     'photo_link': 'https://secure.meetupstatic.com/photos/event/2/e/9/5/600_450131925.jpeg',
#     'thumb_link': 'https://secure.meetupstatic.com/photos/event/2/e/9/5/thumb_450131925.jpeg',
#     'type': 'event',
#     'base_url': 'https://secure.meetupstatic.com'},
#    'category_ids': [22, 24, 28]}},
#  {'score': 1.0,
#   'id': 1466450,
#   'name': 'NE Ohio Natural Family Planning',
#   'status': 'active',
#   'link': 'https://www.meetup.com/NEO-NFP/',
#   'urlname': 'NEO-NFP',
#   'description': '<p>We are families who love life!</p>\n<p>Families who&nbsp;have a common&nbsp;interest in:</p>\n<p>- natural family planning,</p>\n<p>- fertility awareness,</p>\n<p>-&nbsp;natural help for infertility.</p>\n<p>Families who want support and friendship in living:</p>\n<p>- strong, healthy marriages,</p>\n<p>- and raising wholesome, happy children,</p>\n<p>- and understanding Theology of the Body and Catholic life.</p>\n<p>Our meetups are get-togethers and events planned just for our group, like a hike or bowling or a picnic.&nbsp; Most events are kid-friendly but some are for couples, some for the guys or girls.</p>\n<p>This group is supported by a chapter of the Couple to Couple League, an organization&nbsp;of Natural Family Planning teachers,&nbsp;which adheres to&nbsp;and promotes Catholic teaching. We host a&nbsp;comprehensive website for all information about NFP, local resources for individuals and parishes,&nbsp; NFP classes, help with infertility and more&nbsp;at <a href="http://www.neo-nfp.com/main/">neo-nfp.org</a>.&nbsp;It is your local NFP resource.&nbsp; There is a public Facebook group where we post interesting articles and developments in NFP, please friend the page.&nbsp; (See&nbsp;f link) There is also a&nbsp;private NEO-NFP Facebook&nbsp;group specifically for the members of the NE Ohio Natural Family Planning Meetup group&nbsp;&nbsp;to serve as a forum for asking questions/getting support related to NFP, marriage, family, or being Catholic. Befriend an organizer of the group to join it.&nbsp; We hope all of these resources are a great help to you.&nbsp; Please join us, have fun and spread the word about the benefits of NFP!</p>',
#   'created': 1244082485000,
#   'city': 'Cleveland',
#   'untranslated_city': 'Cleveland',
#   'country': 'US',
#   'localized_country_name': 'USA',
#   'localized_location': 'Cleveland, OH',
#   'state': 'OH',
#   'join_mode': 'open',
#   'visibility': 'public',
#   'lat': 41.47,
#   'lon': -81.74,
#   'members': 186,
#   'organizer': {'id': 9690452,
#    'name': 'Tim and Mary Ellen Jakubisin',
#    'bio': 'Mary Ellen & Tim have been involved in marriage prep and natural family planning instruction almost their entire married lives. They took an NFP class from CCL while engaged and early in their marriage became certified NFP instructors.',
#    'photo': {'id': 6817871,
#     'highres_link': 'https://secure.meetupstatic.com/photos/member/9/3/e/f/highres_6817871.jpeg',
#     'photo_link': 'https://secure.meetupstatic.com/photos/member/9/3/e/f/member_6817871.jpeg',
#     'thumb_link': 'https://secure.meetupstatic.com/photos/member/9/3/e/f/thumb_6817871.jpeg',
#     'type': 'member',
#     'base_url': 'https://secure.meetupstatic.com'}},
#   'who': 'NFP Supporters',
#   'group_photo': {'id': 273303242,
#    'highres_link': 'https://secure.meetupstatic.com/photos/event/c/a/a/highres_273303242.jpeg',
#    'photo_link': 'https://secure.meetupstatic.com/photos/event/c/a/a/600_273303242.jpeg',
#    'thumb_link': 'https://secure.meetupstatic.com/photos/event/c/a/a/thumb_273303242.jpeg',
#    'type': 'event',
#    'base_url': 'https://secure.meetupstatic.com'},
#   'key_photo': {'id': 450093272,
#    'highres_link': 'https://secure.meetupstatic.com/photos/event/8/1/f/8/highres_450093272.jpeg',
#    'photo_link': 'https://secure.meetupstatic.com/photos/event/8/1/f/8/600_450093272.jpeg',
#    'thumb_link': 'https://secure.meetupstatic.com/photos/event/8/1/f/8/thumb_450093272.jpeg',
#    'type': 'event',
#    'base_url': 'https://secure.meetupstatic.com'},
#   'timezone': 'US/Eastern',
#   'next_event': {'id': '254682790',
#    'name': 'Eastside Playdate',
#    'yes_rsvp_count': 7,
#    'time': 1537380000000,
#    'utc_offset': -14400000},
#   'category': {'id': 25,
#    'name': 'Parents & Family',
#    'shortname': 'parents-family',
#    'sort_name': 'Parents & Family'},
#   'meta_category': {'id': 232,
#    'shortname': 'parents-family',
#    'name': 'Family',
#    'sort_name': 'Family',
#    'photo': {'id': 450131932,
#     'highres_link': 'https://secure.meetupstatic.com/photos/event/2/e/9/c/highres_450131932.jpeg',
#     'photo_link': 'https://secure.meetupstatic.com/photos/event/2/e/9/c/600_450131932.jpeg',
#     'thumb_link': 'https://secure.meetupstatic.com/photos/event/2/e/9/c/thumb_450131932.jpeg',
#     'type': 'event',
#     'base_url': 'https://secure.meetupstatic.com'},
#    'category_ids': [25]}},
#  {'score': 1.0,
#   'id': 27772594,
#   'name': 'The Breakfast Club (and more) Group',
#   'status': 'active',
#   'link': 'https://www.meetup.com/TheBreakfastClub-and-more/',
#   'urlname': 'TheBreakfastClub-and-more',
#   'description': '<p>Welcome!&nbsp; This group will be just like <b>THE BREAKFAST CLUB</b>, made up of all different types of people . . . but Emilio won\'t be there! We will primarily meet for breakfast and brunches, but will add other types of events ("and more"). Events will be mostly on the weekends, but in the summer months, they might be during the week. There are so many cool places to try in the Cleveland area, both popular and off the beaten path. We will try to post a wide variety of places in a wide variety of cities. It costs $190 annually to run up to three Meetup groups.&nbsp; To help defray the cost, please consider donating a minimum of $5 annually to the organizer.</p>\n<p>Because reservations will be made for most of our events, the restaurant staff will expect the number we tell them. It becomes a problem when we have "no-shows" of our attendees (say YES, but don\'t show up).&nbsp; Please understand that if you "no-show" TWO TIMES you will be removed from the group.&nbsp; You are invited to re-join when your schedule is more conducive.&nbsp; Thanks for your cooperation with this.</p>\n<p>Looking forward to exploring eateries with everybody!</p>',
#   'created': 1520578663000,
#   'city': 'North Royalton',
#   'untranslated_city': 'North Royalton',
#   'country': 'US',
#   'localized_country_name': 'USA',
#   'localized_location': 'North Royalton, OH',
#   'state': 'OH',
#   'join_mode': 'open',
#   'visibility': 'public',
#   'lat': 41.32,
#   'lon': -81.74,
#   'members': 90,
#   'organizer': {'id': 11597179,
#    'name': 'Cynthia D.',
#    'bio': 'My name is Cynthia. I am always up for doing things with a group of people.',
#    'photo': {'id': 276615679,
#     'highres_link': 'https://secure.meetupstatic.com/photos/member/3/d/3/f/highres_276615679.jpeg',
#     'photo_link': 'https://secure.meetupstatic.com/photos/member/3/d/3/f/member_276615679.jpeg',
#     'thumb_link': 'https://secure.meetupstatic.com/photos/member/3/d/3/f/thumb_276615679.jpeg',
#     'type': 'member',
#     'base_url': 'https://secure.meetupstatic.com'}},
#   'who': "Starting your day right'ers",
#   'group_photo': {'id': 469095564,
#    'highres_link': 'https://secure.meetupstatic.com/photos/event/3/c/c/c/highres_469095564.jpeg',
#    'photo_link': 'https://secure.meetupstatic.com/photos/event/3/c/c/c/600_469095564.jpeg',
#    'thumb_link': 'https://secure.meetupstatic.com/photos/event/3/c/c/c/thumb_469095564.jpeg',
#    'type': 'event',
#    'base_url': 'https://secure.meetupstatic.com'},
#   'key_photo': {'id': 469095564,
#    'highres_link': 'https://secure.meetupstatic.com/photos/event/3/c/c/c/highres_469095564.jpeg',
#    'photo_link': 'https://secure.meetupstatic.com/photos/event/3/c/c/c/600_469095564.jpeg',
#    'thumb_link': 'https://secure.meetupstatic.com/photos/event/3/c/c/c/thumb_469095564.jpeg',
#    'type': 'event',
#    'base_url': 'https://secure.meetupstatic.com'},
#   'timezone': 'US/Eastern',
#   'next_event': {'id': '253304842',
#    'name': 'Boozy Brunch Buffet at Crop Bistro',
#    'yes_rsvp_count': 10,
#    'time': 1537720200000,
#    'utc_offset': -14400000},
#   'category': {'id': 10,
#    'name': 'Food & Drink',
#    'shortname': 'food-drink',
#    'sort_name': 'Food & Drink'},
#   'meta_category': {'id': 162,
#    'shortname': 'food',
#    'name': 'Food & Drink',
#    'sort_name': 'Food & Drink',
#    'photo': {'id': 450131937,
#     'highres_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/1/highres_450131937.jpeg',
#     'photo_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/1/600_450131937.jpeg',
#     'thumb_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/1/thumb_450131937.jpeg',
#     'type': 'event',
#     'base_url': 'https://secure.meetupstatic.com'},
#    'category_ids': [10]}},
#  {'score': 1.0,
#   'id': 27879544,
#   'name': 'MindfulCLE',
#   'status': 'active',
#   'link': 'https://www.meetup.com/MindfulCLE/',
#   'urlname': 'MindfulCLE',
#   'description': '<p>Hello!</p>\n<p>We host regular yoga and meditation classes, various styles of healing massages, aerial silks, workshops, education courses, and much more! <br></p>\n<p>Meetups for this group are generally held at: 1395 W. 10th St. Suite 120, Cleveland, OH 44113 </p>\n<p>All yoga and meditation classes are donation-based.&nbsp; </p>\n<br>\n<br>',
#   'created': 1521488174000,
#   'city': 'Cleveland',
#   'untranslated_city': 'Cleveland',
#   'country': 'US',
#   'localized_country_name': 'USA',
#   'localized_location': 'Cleveland, OH',
#   'state': 'OH',
#   'join_mode': 'open',
#   'visibility': 'public',
#   'lat': 41.48,
#   'lon': -81.69,
#   'members': 205,
#   'organizer': {'id': 243984525,
#    'name': 'Sara Syed',
#    'bio': '',
#    'photo': {'id': 275672995,
#     'highres_link': 'https://secure.meetupstatic.com/photos/member/8/0/e/3/highres_275672995.jpeg',
#     'photo_link': 'https://secure.meetupstatic.com/photos/member/8/0/e/3/member_275672995.jpeg',
#     'thumb_link': 'https://secure.meetupstatic.com/photos/member/8/0/e/3/thumb_275672995.jpeg',
#     'type': 'member',
#     'base_url': 'https://secure.meetupstatic.com'}},
#   'who': 'Members',
#   'key_photo': {'id': 473887591,
#    'highres_link': 'https://secure.meetupstatic.com/photos/event/1/d/a/7/highres_473887591.jpeg',
#    'photo_link': 'https://secure.meetupstatic.com/photos/event/1/d/a/7/600_473887591.jpeg',
#    'thumb_link': 'https://secure.meetupstatic.com/photos/event/1/d/a/7/thumb_473887591.jpeg',
#    'type': 'event',
#    'base_url': 'https://secure.meetupstatic.com'},
#   'timezone': 'US/Eastern',
#   'next_event': {'id': 'dvlzcqyxmbbc',
#    'name': 'Powerful Vinyasa Flow - Yoga Class ',
#    'yes_rsvp_count': 1,
#    'time': 1537480800000,
#    'utc_offset': -14400000},
#   'category': {'id': 14,
#    'name': 'Health & Wellbeing',
#    'shortname': 'health-wellbeing',
#    'sort_name': 'Health & Wellbeing'},
#   'meta_category': {'id': 302,
#    'shortname': 'health-wellness',
#    'name': 'Health & Wellness',
#    'sort_name': 'Health & Wellness',
#    'photo': {'id': 450131950,
#     'highres_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/e/highres_450131950.jpeg',
#     'photo_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/e/600_450131950.jpeg',
#     'thumb_link': 'https://secure.meetupstatic.com/photos/event/2/e/a/e/thumb_450131950.jpeg',
#     'type': 'event',
#     'base_url': 'https://secure.meetupstatic.com'},
#    'category_ids': [14, 33]}}]

# %%
result2_df = pd.DataFrame(response2)[['id','name','status','created','city','lat','lon','members','category']]

result2_df = result2_df.set_index('id')
result2_df.drop(result2_df.columns[0], axis=1)
result2_df.sort_values('members', ascending=False, inplace=True)

result2_df.head()
data=[]
for x in result2_df.category:
    data.append(x['name'])
data
result2_df.insert(8,'category_name',data)
result2_df = result2_df.drop('category', axis=1)
result2_df.head()
# Out:
#                                        name  status        created  \
# id
# 693119        The Cleveland 20s & 30s Group  active  1190135836000
# 7854222           Enjoy Outside - Cleveland  active  1364734329000
# 1603993          Northeast Ohio Hiking Club  active  1266952168000
# 494930                      nEo Adventurers  active  1178507477000
# 593120   Cleveland Beer Lovers Meetup Group  active  1185754963000
#
#                  city    lat    lon  members         category_name
# id
# 693119      Cleveland  41.51 -81.68     8414           Socializing
# 7854222  Independence  41.38 -81.66     6384  Outdoors & Adventure
# 1603993     Cleveland  41.38 -81.79     6091  Outdoors & Adventure
# 494930      Cleveland  41.52 -81.56     6084  Outdoors & Adventure
# 593120      Cleveland  41.38 -81.79     5340           Socializing

# %%
result2_df.to_csv("/Users/bryandickens/Desktop/Project_1_MeetupAPI/Project_1_MeetupAPI/MeetupMembership.csv", 
                  index=False, header=True)

# %%
result3_df = result2_df

# %%
result3_df['category_name'] = result3_df['category_name'].replace(
    {'Fitness': 'Other', 
     'Movies & Film': 'Other',
     'Language & Ethnic Identity': 'Other',
     'New Age & Spirituality': 'Other',
     'Support': 'Other',
     'Religion & Beliefs': 'Other',
     'Writing': 'Other',
     'Singles': 'Other',
     'Health & Wellbeing': 'Other',
     'Music': 'Other',
     'Sci-Fi & Fantasy': 'Other',
     'Lifestyle': 'Other',
     'Education & Learning': 'Other',
     'Arts & Culture': 'Other',
     'Cars & Motorcycles': 'Other',
     'Book Clubs': 'Other',
     'Community & Environment': 'Other',
     'LGBT': 'Other',
     'Parents & Family': 'Other',
     'Hobbies & Crafts': 'Other'})
result3_df.head()
# Out:
#                                        name  status        created  \
# id
# 693119        The Cleveland 20s & 30s Group  active  1190135836000
# 7854222           Enjoy Outside - Cleveland  active  1364734329000
# 1603993          Northeast Ohio Hiking Club  active  1266952168000
# 494930                      nEo Adventurers  active  1178507477000
# 593120   Cleveland Beer Lovers Meetup Group  active  1185754963000
#
#                  city    lat    lon  members         category_name
# id
# 693119      Cleveland  41.51 -81.68     8414           Socializing
# 7854222  Independence  41.38 -81.66     6384  Outdoors & Adventure
# 1603993     Cleveland  41.38 -81.79     6091  Outdoors & Adventure
# 494930      Cleveland  41.52 -81.56     6084  Outdoors & Adventure
# 593120      Cleveland  41.38 -81.79     5340           Socializing

# %%
result3_df.set_index('category_name',inplace=True)

# %%
result3_df.drop(['name','status','created','city','lat','lon'], axis=1, inplace=True)

# %%
result3_df = result3_df.pivot_table(values='members', index='category_name', aggfunc='sum')
result3_df.sort_values('members',ascending=False, inplace=True)
result3_df
# Out:
#                       members
# category_name
# Other                   48530
# Socializing             39317
# Outdoors & Adventure    34023
# Tech                    23152
# Food & Drink            17960
# Career & Business       17925
# Games                   10667
# Dancing                  9328
# Sports & Recreation      8412

# %%
result3_df.plot(kind='pie',subplots=True,title='Cleveland Meetup Members by Category',
               autopct='%.1f')
plt.axis('equal')
import pylab
pylab.ylabel('')

plt.legend(loc=0,bbox_to_anchor=(1, .3),fontsize='medium',shadow=True)
plt.tight_layout()
plt.savefig('pie chart')
plt.show()

# %%
# Store latitude and longitude in locations
locations = result2_df[['lat','lon']]

# Fill NaN values and convert to float
rating = result2_df["members"].astype(int)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-267-4d418f8b23fd> in <module>()
#       1 # Store latitude and longitude in locations
# ----> 2 locations = result2_df[['lat','lon']]
#       3
#       4 # Fill NaN values and convert to float
#       5 rating = result2_df["members"].astype(int)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2677         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2678             # either boolean or fancy integer index
# -> 2679             return self._getitem_array(key)
#    2680         elif isinstance(key, DataFrame):
#    2681             return self._getitem_frame(key)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2721             return self._take(indexer, axis=0)
#    2722         else:
# -> 2723             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2724             return self._take(indexer, axis=1)
#    2725
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1325                 if mask.any():
#    1326                     raise KeyError('{mask} not in index'
# -> 1327                                    .format(mask=objarr[mask]))
#    1328
#    1329                 return com._values_from_object(indexer)
#
# KeyError: "['lat' 'lon'] not in index"

# %%
# Plot as a Hybrid map
fig = gmaps.figure(map_type="HYBRID")

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=rating, 
                                 dissipating=True, max_intensity=1000,
                                 point_radius=13)

fig.add_layer(heat_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
max_mem = result2_df['members'].max()
min_mem = result2_df['members'].min()
count_mem = result2_df['members'].sum()
#max_mem_group = 
#max_mem_group =
mem_group = count_mem/mem_count

print('Group with the most members')
print('---------------------------')
print(max_mem)
print()
print('Group with the least members')
print('---------------------------')
print(min_mem)
print()
print('Total member count')
print('---------------------------')
print(count_mem)
print('---------------------------')
print('On average, each Meetup member subscribes to ' + str(round(mem_group,1)) + ' groups')
# Out:
# Group with the most members
# ---------------------------
# 8414
#
# Group with the least members
# ---------------------------
# 20
#
# Total member count
# ---------------------------
# 209314
# ---------------------------
# On average, each Meetup member subscribes to 6.4 groups

# %%
pivot_df = result2_df.pivot_table(values='members', index='category_name', aggfunc='sum')
pivot_df.head()
# Out:
#                    members
# category_name
# Career & Business    17925
# Dancing               9328
# Food & Drink         17960
# Games                10667
# Other                48530

# %%
count_mem = result2_df['members'].sum()

pivot_df['percent_of_total'] = round(pivot_df['members'] / count_mem * 100,2)

pivot_df.sort_values('percent_of_total', ascending=False, inplace=True)
pivot_df.head()
# Out:
#                       members  percent_of_total
# category_name
# Other                   48530             23.19
# Socializing             39317             18.78
# Outdoors & Adventure    34023             16.25
# Tech                    23152             11.06
# Food & Drink            17960              8.58
